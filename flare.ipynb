# %%
import os
import glob

import matplotlib.pyplot as plt
import numpy as np


from utils import read_Tumag
import image_handler as ih

# %%
mag_fold = "/home/pablo/Desktop/TuMAGDATA/flare_set_ordered/1/23"


all_ims = np.array(sorted(glob.glob(f"{mag_fold}/*")))


mode1 = ih.nominal_observation("1", all_ims)

# %%
data = mode1.get_data()

# %%
np.shape(data)
# Out:
# (2, 10, 4, 2016, 2016)

# %%
for i in range(10):
    fig, axs = plt.subplots(1, 2, figsize = (10, 5))
    axs[0].imshow(data[0, i, 0], cmap = "gray", vmax = 20000)
    axs[1].imshow(data[1, i, 0], cmap = "gray", vmax = 20000)

    plt.tight_layout()
    plt.show()

# %%
mag_fold = "/home/pablo/Desktop/TuMAGDATA/flare_set_ordered/2.06/24"


all_ims = np.array(sorted(glob.glob(f"{mag_fold}/*")))


mode206 = ih.nominal_observation("2.06", all_ims)

# %%
data = mode206.get_data()

for i in range(8):
    fig, axs = plt.subplots(1, 2, figsize = (10, 5))
    axs[0].imshow(data[0, i, 0], cmap = "gray", vmax = 25000)
    axs[1].imshow(data[1, i, 0], cmap = "gray", vmax = 25000)

    plt.tight_layout()
    plt.show()
