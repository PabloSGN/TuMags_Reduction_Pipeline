# %%
import sys
import matplotlib.pyplot as plt

sys.path.append("/home/pablo/Desktop/TuMag/TuMags_Reduction_Pipeline")
import image_handler as ih

# %%
I, H = ih.read_ID("D11", 4000)

print("OC", H["ObservationCounter"])

print("OM", H["ObservationMode"])

plt.figure(figsize = (10, 10))
plt.imshow(I, cmap = "gray")
# Out:
# /media/pablo/2b2c0b5a-0b6a-4279-8945-6a6751cd232f/TUMAG/2024_07_11_00_00_00_123/2024_07_11_02_00_01_205/2024_07_11_02_29_28_634_0_817.img
# OC 140
# OM 1
